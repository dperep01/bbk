# %%
df = pd.read_pickle('data/CMCUF-fc-px')

#iplot(go.Figure(
#    data=[go.Surface(x=df.columns,y=df.index.values.astype(str),z=df.values)],
#    layout=go.Layout(
#        title='LME Copper Forward Curve',
#        autosize=False,width=800,height=500,
#        margin=dict(l=10,r=50,b=65,t=90),    
#        scene={'xaxis':{'title':'Maturity (month)'}, 'yaxis':{'tickformat': '%Y-%m-%d'}, 'zaxis':{'title':'Spread %'}},
#        showlegend=False,
#    )))
#

# %%
df = pd.read_pickle('data/CMCUc')
(df[df.RIC=='CMCUc6'].Price/df[df.RIC=='CMCUc1'].Price-1).plot(figsize=(12,10), grid=True, marker='o')
ax = df[df.RIC=='CMCUc1'].plot(y='Price', marker='o', figsize=(12,10))
ax = df[df.RIC=='CMCUc6'].plot(y='Price', marker='o', ax=ax, grid=True)

# %%
df = pd.read_pickle('data/CMCUc_fc_spread')
df.plot(y=1)
df
# Out:
#             0            1            2            3            4  \
# Date
# 2011-01-11  0   0.00103634   0.00161928   0.00181359   0.00220222
# 2011-01-12  0   0.00122234   0.00209727   0.00299794   0.00353834
# 2011-02-11  0   0.00107943    0.0015874   0.00177789   0.00222236
# 2011-02-12  0   0.00120692   0.00212163   0.00294742    0.0034937
# 2011-03-11  0    0.0011637   0.00158112   0.00158112   0.00198588
# 2011-04-11  0   0.00129832    0.0019984   0.00216387   0.00260937
# 2011-05-12  0   0.00113608   0.00199445   0.00277708   0.00334511
# 2011-06-12  0   0.00111306     0.002047   0.00284022   0.00341594
# 2011-07-11  0   0.00131882   0.00198464   0.00221511   0.00268886
# 2011-07-12  0   0.00121803   0.00217963   0.00307712   0.00362844
# 2011-08-11  0   0.00132289   0.00183663   0.00202928    0.0025045
# 2011-08-12  0   0.00123532   0.00217157   0.00301679   0.00366696
# 2011-09-11  0   0.00137994   0.00201078   0.00229991   0.00289131
# ...
