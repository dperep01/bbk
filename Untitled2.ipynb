# %%
#from matplotlib import pylab as plt
#fig, ax = plt.subplots(figsize=(20,7))
df = pd.read_csv('data/SCF-with-expiry.csv', parse_dates=['Date', 'Exp'], infer_datetime_format=True)
df.sort_values(['Date', 'RIC'])[df.Date>='2018-1-16'].head()


#df.query('Date >= "2018-1-2"').head()
#.plot(x='Expiry', y='Close', ax=ax)
# Out:
# /Users/xren/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#          RIC       Date    Close        Exp   CRIC
# 4135   SCFF9 2018-01-16  55950.0 2019-01-16  2019F
# 7985   SCFG8 2018-01-16  54420.0 2018-02-09  2018G
# 12361  SCFH8 2018-01-16  54600.0 2018-03-15  2018H
# 16961  SCFJ8 2018-01-16  54650.0 2018-04-16  2018J
# 21265  SCFK8 2018-01-16  54840.0 2018-05-15  2018K

# %%
#df = pd.read_csv('data/SCF.csv', parse_dates=['Trade Date'], infer_datetime_format=True)
#df[df.RIC=='SCFG8'].sort_values('Trade Date').tail(30)
df = pd.read_csv('data/SCF-expiry.csv', parse_dates=['Exp'], infer_datetime_format=True)
df[df.RIC=='SCFF9'].tail()
#df.loc['SCFV8'].sort_values('Exp')
# Out:
#        RIC   CRIC        Exp
# 18   SCFF9  2009F 2009-01-15
# 19   SCFF9  2018F 2018-11-02
# 242  SCFF9  2019F 2019-01-16

# %%
df = pd.read_csv('data/SCF-fc-3d.csv', parse_dates=['Date'], infer_datetime_format=True)
df[df.Date>='2018-1-15']
# Out:
#            Date        0        1        2        3        4        5  \
# 4485 2018-01-15  54320.0  54530.0  54670.0  54850.0  55020.0  55220.0
# 4486 2018-01-16  55950.0  54420.0  54600.0  54650.0  54840.0  55070.0
# 4487 2018-01-17  55360.0  53690.0  53800.0  53910.0  54060.0  54230.0
# 4488 2018-01-18  55250.0  53590.0  53680.0  53840.0  53960.0  54160.0
# 4489 2018-01-19  55140.0  53560.0  53710.0  53830.0  53970.0  54160.0
# 4490 2018-01-22  55110.0  53500.0  53600.0  53760.0  53920.0  54080.0
# 4491 2018-01-23  55260.0  53490.0  53640.0  53780.0  53950.0  54120.0
# 4492 2018-01-24  54430.0  52630.0  52760.0  52910.0  53060.0  53230.0
# 4493 2018-01-25  55420.0  53470.0  53560.0  53710.0  53960.0  54280.0
# 4494 2018-01-26  55210.0  53380.0  53550.0  53690.0  53830.0  54020.0
# 4495 2018-01-29  55250.0  53370.0  53470.0  53630.0  53800.0  54030.0
# 4496 2018-01-30  54700.0  53040.0  53260.0  53360.0  53510.0  53670.0
# ...
