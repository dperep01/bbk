# %%
from matplotlib import pylab as plt
fig, ax = plt.subplots(figsize=(20,7))
df = pd.read_csv('SCF-with-expiry.csv', parse_dates=True, index_col=1)
df['2016-1-15':'2016-1-15'].sort_values('CRIC')
#.plot(x='Expiry', y='Close', ax=ax)
# Out:
#               RIC    Close               Expiry   CRIC
# Date
# 2016-01-15  SCFF6  34900.0  2016-01-15 00:00:00  2016F
# 2016-01-15  SCFG6  35040.0  2016-02-15 00:00:00  2016G
# 2016-01-15  SCFH6  35010.0  2016-03-15 00:00:00  2016H
# 2016-01-15  SCFJ6  34970.0  2016-04-15 00:00:00  2016J
# 2016-01-15  SCFK6  34930.0  2016-05-16 00:00:00  2016K
# 2016-01-15  SCFM6  34890.0  2016-06-15 00:00:00  2016M
# 2016-01-15  SCFN6  34920.0  2016-07-15 00:00:00  2016N
# 2016-01-15  SCFQ6  34980.0  2016-08-15 00:00:00  2016Q
# 2016-01-15  SCFU6  34870.0  2016-09-19 00:00:00  2016U
# 2016-01-15  SCFV6  34840.0  2016-10-17 00:00:00  2016V
# 2016-01-15  SCFX6  34860.0  2016-11-15 00:00:00  2016X
# 2016-01-15  SCFZ6  34760.0  2016-12-15 00:00:00  2016Z
