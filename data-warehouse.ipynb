# %%
# xlsx = pd.ExcelFile('data/COMEX-COPPER-STOCKS.xlsx')
# comex = pd.read_excel(xlsx, 'HG-STX-COMEX').set_index('Date').rename(columns={'Volume':'COMEX Total Stock'})
# comex.head()
# #ax = df.plot()
# #df = pd.read_excel(xlsx, 'HG-STXTW-STX').set_index('Date')
# df.plot(ax=ax, grid=True)
# on_warrant = pd.read_csv('data/SCF-TOTAL-W.csv', index_col=0, parse_dates=True, dayfirst=True).rename(
#    columns={'OnWarrant':'SHFE On Warrant'}
# ).sort_index()
# on_warrant.head()
# delivery = pd.read_csv('data/CU-STX-SGH.csv', index_col=0, parse_dates=True, dayfirst=True).rename(
#    columns = {'Deliverable':'SHFE Deliverable'}
# ).sort_index()
# delivery.head()
# lme = pd.read_pickle('data/LME-stocks').rename(columns={'volume':'LME Total Stock'})
# lme.head()
# df = pd.concat([comex, on_warrant, delivery, lme], axis=1)
# df['Total'] = df[['COMEX Total Stock','SHFE Deliverable','LME Total Stock']].sum(axis=1)
# df.to_pickle('data/inventory.pkl')
# Out:
#             COMEX Total Stock
# Date
# 2008-01-01              15230
# 2008-01-02              15317
# 2008-01-03              15091
# 2008-01-04              14931
# 2008-01-07              14926
#             SHFE On Warrant
# Date
# 2008-01-04             9894
# 2008-01-11             8795
# 2008-01-18            17785
# 2008-01-25            10115
# 2008-02-01             8797
#             SHFE Deliverable
# Date
# 2008-01-02             25597
# 2008-01-03             24148
# 2008-01-04             24148
# 2008-01-07             24148
# 2008-01-08             24148
#             LME Total Stock
# date
# 1998-11-12           478400
# 1998-11-13           480200
# 1998-11-16           480700
# 1998-11-17           482400
# 1998-11-18           483175

# %%
inv = pd.read_pickle('data/inventory.pkl').dropna().plot()
