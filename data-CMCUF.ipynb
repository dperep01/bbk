# %%
df = pd.read_csv('data/CMCUF.csv', parse_dates=['Trade Date'], dayfirst=True).rename(columns={'Trade Date':'Date', 'Universal Close Price':'Price'})[['RIC', 'Date', 'Price', 'Volume']]
#df['TT'] = pd.to_numeric(df.RIC.str.extract('(\d+)')[0])-1
df.set_index('Date', inplace=True)
