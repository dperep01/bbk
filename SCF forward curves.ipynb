# %%
df = pd.read_pickle('data/SCFc-fc-px')['2008-10':'2009-3'][['SCFc01', 'SCFc08','SCFc09']]
df.plot(figsize=(12,10), grid=True)

# %%
df = pd.read_csv('/Users/xren/SCF.csv', parse_dates=['Dates'], infer_datetime_format=True, index_col=0)
df = df[['CLOSEPRICE']]
df2 = pd.read_csv('/Users/xren/SCF2.csv', parse_dates=['Dates'], infer_datetime_format=True, index_col=0)
df2 = df2[['CLOSEPRICE']]
#df2 = df2.add_suffix('_2')
fig, ax = plt.subplots(figsize=(15,7))
df['2018-1-1':].plot(ax=ax, grid=True)
df2['2018-1-1':].plot(ax=ax, grid=True)
dfm = pd.merge(df, df2, left_index=True,right_index=True)
dfm['2018-1-1':].plot(ax=ax, grid=True)
(df-df2).sum()
# Out:
# CLOSEPRICE    0.0
# dtype: float64

# %%
df
# Out:
#             CLOSEPRICE
# Dates
# 2008-01-04     60970.0
# 2008-01-07     60790.0
# 2008-01-08     60970.0
# 2008-01-09     62740.0
# 2008-01-10     62320.0
# 2008-01-11     62630.0
# 2008-01-14     63440.0
# 2008-01-15     62630.0
# 2008-01-16     60370.0
# 2008-01-17     60810.0
# 2008-01-18     61000.0
# 2008-01-21     62160.0
# 2008-01-22     59940.0
# 2008-01-23     60660.0
# 2008-01-24     61110.0
# 2008-01-25     61560.0
# 2008-01-28     60700.0
# 2008-01-29     61240.0
# 2008-01-30     61960.0
# 2008-01-31     61990.0
# 2008-02-01     62760.0
# 2008-02-04     62760.0
# 2008-02-05     63050.0
# 2008-02-13     64870.0
# 2008-02-14     64240.0
# 2008-02-15     63890.0
# 2008-02-18     64790.0
# 2008-02-19     66060.0
# 2008-02-20     66080.0
# 2008-02-21     66440.0
# ...                ...
# 2018-09-05     47420.0
# 2018-09-06     47740.0
# 2018-09-07     47820.0
# 2018-09-10     47760.0
# 2018-09-11     47930.0
# 2018-09-12     47860.0
# 2018-09-13     48620.0
# 2018-09-14     48770.0
# 2018-09-17     48210.0
# 2018-09-18     48620.0
# 2018-09-19     49660.0
# 2018-09-20     49630.0
# 2018-09-21     49880.0
# 2018-09-25     50410.0
# 2018-09-26     50700.0
# 2018-09-27     50500.0
# 2018-09-28     50240.0
# 2018-10-08     50220.0
# 2018-10-09     50510.0
# 2018-10-10     50910.0
# 2018-10-11     50130.0
# 2018-10-12     50610.0
# 2018-10-15     50780.0
# 2018-10-16     50510.0
# 2018-10-17     50230.0
# 2018-10-18     50280.0
# 2018-10-19     50080.0
# 2018-10-22     50450.0
# 2018-10-23     50330.0
# 2018-10-24     50090.0
#
# [2627 rows x 1 columns]
