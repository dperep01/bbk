# %%
from matplotlib import pylab as plt
fig, ax = plt.subplots(figsize=(15,7))
df = pd.read_csv('SCF.csv', parse_dates=['Trade Date'], infer_datetime_format=True)[['RIC', 'Trade Date', 'Universal Close Price']]
df = df[df['Trade Date'] > '2010-1-1']
for name, group in df.groupby('RIC').tail(30).groupby('RIC'):
    ax.plot(group['Trade Date'], group['Universal Close Price'], label=name)
#ax.legend()
ax.grid()

#.tail(3).groupby('RIC').plot(x='Trade Date', y='Universal Close Price',ax=ax, marker='.', legend=True, grid=True)
#df.groupby('RIC').plot(y='Open', ax=ax)
#df[df.RIC=='SCFF0'].plot(x='Trade Date', y='Universal Close Price', ax=ax, grid=True)

#df = df.groupby('RIC').apply(lambda x: x.set_index('Trade Date').resample('1D').first())

#df = df.groupby('RIC', as_index=True).max()
#df[df.index=='SCFF9']

# %%
df = pd.read_csv('/Users/xren/SCF.csv', parse_dates=['Dates'], infer_datetime_format=True, index_col=0)
df = df[['CLOSEPRICE']]
df2 = pd.read_csv('/Users/xren/SCF2.csv', parse_dates=['Dates'], infer_datetime_format=True, index_col=0)
df2 = df2[['CLOSEPRICE']]
#df2 = df2.add_suffix('_2')
fig, ax = plt.subplots(figsize=(15,7))
df['2018-1-1':].plot(ax=ax, grid=True)
df2['2018-1-1':].plot(ax=ax, grid=True)
dfm = pd.merge(df, df2, left_index=True,right_index=True)
dfm['2018-1-1':].plot(ax=ax, grid=True)
(df-df2).sum()
# Out:
# CLOSEPRICE    0.0
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15,7))
dfm.plot(y='CLOSEPRICE_2', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-90bb21a260e8> in <module>()
#       1 fig, ax = plt.subplots(figsize=(15,7))
# ----> 2 dfm.plot(y='CLOSEPRICE_2', ax=ax)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...
